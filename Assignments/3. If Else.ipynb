# %%
if():
    print()
else:
    print

# %%
age=int(input("Enter the age"))
# Out:
# Enter the age 10

# %%
if(age<18):
    print("children")
else:
    print("adult")
# Out:
# children

# %%
if 0:
    print("Hello")
else:
    print("World")
# Out:
# World

# %%
print("python"+"programming")
# Out:
# pythonprogramming

# %%
def test():
    return 5
print(test()+10)
# Out:
# 15

# %% [markdown]
# x="hello"
# print(x[1])

# %%
x=5
y=x
x=10
print(y)
# Out:
# 5

# %%
for i in range(3):
    print(i)
# Out:
# 0
# 1
# 2
