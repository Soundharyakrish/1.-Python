# %%
Lists=[23,45,67,34,89]

# %%
def AgeCategory():
    for age in Lists:
        if(age<18):
             print("children")
        elif(age<35):
             print("adult")
        elif(age<59):
             print("citizen")
        else:
             print("senior citizen")

# %%
AgeCategory()
# Out:
# adult
# citizen
# senior citizen
# adult
# senior citizen

# %%
age=int(input("Enter the age:"))
# Out:
# Enter the age: 50

# %%
def AgeCategory():
        if(age<18):
             print("Children")
             cate="Children"
        elif(age<35):
             print("adult")
             cate="adult"
        elif(age<59):
             print("citizen")
             cate="citizen"
        else:
             print("senior citizen")
             cate="senior citizen"
        return cate

# %%
AgeCategory()
# Out:
# citizen
# 'citizen'
