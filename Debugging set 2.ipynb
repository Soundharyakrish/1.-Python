# %%
##1.Find the error in the following Python code
import math
print(math.sqrt(16))
# Out:
# 4.0

# %%
#2.Find the error in the following Python code
def my_function():
    x+=5
    print(x)
    x=10
    my_function()

# %%
#3.x = 5
x = 5
if x == 10:
    print("x is 10")

# %%
#4
numbers = [5, 3, 8, 2]
numbers.sort()
print(numbers)
# Out:
# [2, 3, 5, 8]

# %%
#5.
def square(n):
    n*n
print(square(4))
# Out:
# None

# %%
#6.
my_tuple=(9, 1, 2, 3)
my_tuple1=5

# %%
#7.
name="Alice"
age=25
print("My name is" ,name  and "I am"  , age , "years old" )
# Out:
# My name is I am 25 years old

# %%
#8.
a = [1, 2, 3]
b = [1, 2, 3]
if a == b:
    print("Lists are equal")
# Out:
# Lists are equal

# %%
#9.
for i in range(1,5):
    print(i)
# Out:
# 1
# 2
# 3
# 4

# %%
#10
student = {"name":"Alice","age": 20}
print(name,age)
# Out:
# Alice 25
